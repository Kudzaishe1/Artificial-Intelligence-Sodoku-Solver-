# %% [markdown]
# <a href="https://colab.research.google.com/github/Kudzaishe1/Artificial-Intelligence-Sodoku-Solver-/blob/master/Face_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Lets make millions")
# Out:
# Lets make millions

# %%
import cv2

# %%
imagePath = '/85baaaaf-b439-49c4-99f8-1475764043b3.jpeg'
img = cv2.imread(imagePath)
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
face_classifier = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

#Side Face

# %%
face = face_classifier.detectMultiScale(
    gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(40, 40)
)

# %%
for (x, y, w, h) in face:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 4)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (-0.5, 748.5, 738.5, -0.5)
